# %%
import os
import numpy as np
from moviepy.editor import ImageSequenceClip

path = os.path.abspath('.')
fps = 1
images_list = []
filename = path + "/embeddings.gif"
image_path = './images_epoch50.npy'


images = np.load(image_path)
images_list = [images[i] for i in range(len(images))]
clip = ImageSequenceClip(images_list, fps=fps)
clip.write_gif(filename, fps=fps)
# Out:
# MoviePy - Building file /home/lizhenyu/Project/E2DTC/data/gnn/embeddings/embeddings.gif with imageio.

# %%
import os
os.path.abspath('.')
# Out:
# '/home/lizhenyu/Project/E2DTC/data/gnn/embeddings'

# %%
from IPython.core.display_functions import display
from IPython.display import Image

with open(filename, 'rb') as f:
    display(Image(data=f.read(), format='png'))
